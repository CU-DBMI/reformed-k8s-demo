# %% [markdown]
# # Trying Out Reformed
#
# If you've followed the tutorial in the README, you should now have Reformed running at http://localhost:8005. If you used the ingress, be sure to modify `REFORMED_BASE_URL` below to point to the URL you mapped to the service.

# %%
# specifies where to access the reformed API
REFORMED_BASE_URL='http://localhost:8005/api/v1'

# %% [markdown]
# Now, let's try to pull a list of formats that Reformed can convert between using `requests` to hit the `/formats` endpoint.

# %%
import requests
import os
from pprint import pprint # to prettyprint the response

target_url = os.path.join(REFORMED_BASE_URL, "formats")
print(f"Accessing {target_url}...")
resp = requests.get(target_url)

pprint(resp.json())
# Out:
# Accessing http://localhost:8005/api/v1/formats...
# {'input': {'commonmark': {'detail': 'CommonMark Markdown',
#                           'ext': 'md',
#                           'mime': 'text/markdown'},
#            'commonmark_x': {'detail': 'CommonMark Markdown with extensions',
#                             'ext': 'md',
#                             'mime': 'text/markdown'},
#            'creole': {'detail': 'Creole 1.0',
#                       'ext': 'txt',
#                       'mime': 'text/plain'},
#            'csv': {'detail': 'CSV table', 'ext': 'csv', 'mime': 'text/csv'},
#            'docbook': {'detail': 'DocBook',
#                        'ext': 'dbk',
#                        'mime': 'application/sgml'},
#            'docx': {'detail': 'Word docx',
#                     'ext': 'docx',
#                     'mime': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document'},
#            'dokuwiki': {'detail': 'DokuWiki markup',
#                         'ext': 'txt',
#                         'mime': 'text/plain'},
#            'epub': {'detail': 'EPUB',
#                     'ext': 'epub',
#                     'mime': 'application/epub+zip'},
#            'fb2': {'detail': 'FictionBook2 e-book',
#                    'ext': 'fb2',
#                    'mime': 'text/xml'},
#            'gfm': {'detail': 'GitHub-Flavored Markdown',
#                    'ext': 'md',
#                    'mime': 'text/markdown'},
#            'haddock': {'detail': 'Haddock markup',
#                        'ext': 'txt',
#                        'mime': 'text/plain'},
#            'html': {'detail': 'HTML', 'ext': 'html', 'mime': 'text/html'},
#            'ipynb': {'detail': 'Jupyter notebook',
#                      'ext': 'ipynb',
#                      'mime': 'application/x-ipynb+json'},
#            'jira': {'detail': 'Jira/Confluence wiki markup',
#                     'ext': 'txt',
#                     'mime': 'text/plain'},
#            'json': {'detail': 'JSON version of native AST',
#                     'ext': 'json',
#                     'mime': 'application/json'},
#            'latex': {'detail': 'LaTeX', 'ext': 'tex', 'mime': 'text/x-tex'},
#            'man': {'detail': 'roff man',
#                    'ext': 'man',
#                    'mime': 'application/x-troff-man'},
#            'markdown': {'detail': "Pandoc's Markdown",
#                         'ext': 'md',
#                         'mime': 'text/markdown'},
#            'markdown_mmd': {'detail': 'MultiMarkdown',
#                             'ext': 'txt',
#                             'mime': 'text/plain'},
#            'markdown_phpextra': {'detail': 'PHP Markdown Extra',
#                                  'ext': 'txt',
#                                  'mime': 'text/markdown'},
#            'markdown_strict': {'detail': 'original unextended Markdown',
#                                'ext': 'md',
#                                'mime': 'text/markdown'},
#            'mediawiki': {'detail': 'MediaWiki markup',
#                          'ext': 'txt',
#                          'mime': 'text/plain'},
#            'muse': {'detail': 'Muse', 'ext': 'muse', 'mime': 'text/plain'},
#            'native': {'detail': 'native Haskell',
#                       'ext': 'hs',
#                       'mime': 'text/x-haskell'},
#            'odt': {'detail': 'OpenOffice text document',
#                    'ext': 'odt',
#                    'mime': 'application/vnd.oasis.opendocument.text'},
#            'opml': {'detail': 'OPML', 'ext': 'opml', 'mime': 'text/x-opml'},
#            'org': {'detail': 'Emacs Org mode',
#                    'ext': 'org',
#                    'mime': 'text/org'},
#            'rst': {'detail': 'reStructuredText',
#                    'ext': 'rst',
#                    'mime': 'text/x-rst'},
#            't2t': {'detail': 'txt2tags', 'ext': 'txt', 'mime': 'text/plain'},
#            'textile': {'detail': 'Textile',
#                        'ext': 'textile',
#                        'mime': 'text/x-textile'},
#            'tikiwiki': {'detail': 'TikiWiki markup',
#                         'ext': 'txt',
#                         'mime': 'text/plain'},
#            'twiki': {'detail': 'TWiki markup',
#                      'ext': 'txt',
#                      'mime': 'text/plain'},
#            'vimwiki': {'detail': 'Vimwiki',
#                        'ext': 'txt',
#                        'mime': 'text/plain'}},
#  'output': {'asciidoc': {'detail': 'AsciiDoc',
#                          'ext': 'adoc',
#                          'mime': 'text/plain'},
#             'asciidoctor': {'detail': 'AsciiDoctor',
#                             'ext': 'adoc',
#                             'mime': 'text/plain'},
#             'beamer': {'detail': 'LaTeX beamer slide show',
#                        'ext': 'tex',
#                        'mime': 'text/x-tex'},
#             'commonmark': {'detail': 'CommonMark Markdown',
#                            'ext': 'md',
#                            'mime': 'text/markdown'},
#             'commonmark_x': {'detail': 'CommonMark Markdown with extensions',
#                              'ext': 'md',
#                              'mime': 'text/markdown'},
#             'context': {'detail': 'ConTeXt',
#                         'ext': 'tex',
#                         'mime': 'text/x-tex'},
#             'docbook': {'detail': 'DocBook 4',
#                         'ext': 'dbk',
#                         'mime': 'application/sgml'},
#             'docbook4': {'detail': 'DocBook 4',
#                          'ext': 'dbk',
#                          'mime': 'application/sgml'},
#             'docbook5': {'detail': 'DocBook 5',
#                          'ext': 'dbk',
#                          'mime': 'application/sgml'},
#             'docx': {'detail': 'Word docx',
#                      'ext': 'docx',
#                      'mime': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document'},
#             'dokuwiki': {'detail': 'DokuWiki markup',
#                          'ext': 'txt',
#                          'mime': 'text/plain'},
#             'dzslides': {'detail': 'DZSlides HTML5 + JavaScript slide show',
#                          'ext': 'html',
#                          'mime': 'text/html'},
#             'epub': {'detail': 'EPUB v3 book',
#                      'ext': 'epub',
#                      'mime': 'application/epub+zip'},
#             'epub2': {'detail': 'EPUB v2',
#                       'ext': 'epub',
#                       'mime': 'application/epub+zip'},
#             'epub3': {'detail': 'EPUB v3 book',
#                       'ext': 'epub',
#                       'mime': 'application/epub+zip'},
#             'fb2': {'detail': 'FictionBook2 e-book',
#                     'ext': 'fb2',
#                     'mime': 'text/xml'},
#             'gfm': {'detail': 'GitHub-Flavored Markdown',
#                     'ext': 'md',
#                     'mime': 'text/markdown'},
#             'haddock': {'detail': 'Haddock markup',
#                         'ext': 'txt',
#                         'mime': 'text/plain'},
#             'html': {'detail': 'HTML, i.e. HTML5/XHTML polyglot markup',
#                      'ext': 'html',
#                      'mime': 'text/html'},
#             'html4': {'detail': 'XHTML 1.0 Transitional',
#                       'ext': 'html',
#                       'mime': 'application/xhtml+xml'},
#             'html5': {'detail': 'HTML, i.e. HTML5/XHTML polyglot markup',
#                       'ext': 'html',
#                       'mime': 'text/html'},
#             'ipynb': {'detail': 'Jupyter notebook',
#                       'ext': 'ipynb',
#                       'mime': 'application/x-ipynb+json'},
#             'jira': {'detail': 'Jira/Confluence wiki markup',
#                      'ext': 'txt',
#                      'mime': 'text/plain'},
#             'json': {'detail': 'JSON version of native AST',
#                      'ext': 'json',
#                      'mime': 'application/json'},
#             'latex': {'detail': 'LaTeX', 'ext': 'tex', 'mime': 'text/x-tex'},
#             'man': {'detail': 'roff man',
#                     'ext': 'man',
#                     'mime': 'application/x-troff-man'},
#             'markdown': {'detail': "Pandoc's Markdown",
#                          'ext': 'md',
#                          'mime': 'text/markdown'},
#             'markdown_mmd': {'detail': 'MultiMarkdown',
#                              'ext': 'txt',
#                              'mime': 'text/plain'},
#             'markdown_phpextra': {'detail': 'PHP Markdown Extra',
#                                   'ext': 'txt',
#                                   'mime': 'text/markdown'},
#             'markdown_strict': {'detail': 'original unextended Markdown',
#                                 'ext': 'md',
#                                 'mime': 'text/markdown'},
#             'mediawiki': {'detail': 'MediaWiki markup',
#                           'ext': 'txt',
#                           'mime': 'text/plain'},
#             'ms': {'detail': 'roff ms',
#                    'ext': 'ms',
#                    'mime': 'application/x-troff-ms'},
#             'muse': {'detail': 'Muse', 'ext': 'muse', 'mime': 'text/plain'},
#             'native': {'detail': 'native Haskell',
#                        'ext': 'hs',
#                        'mime': 'text/x-haskell'},
#             'odt': {'detail': 'OpenOffice text document',
#                     'ext': 'odt',
#                     'mime': 'application/vnd.oasis.opendocument.text'},
#             'opendocument': {'detail': 'OpenDocument',
#                              'ext': 'xml',
#                              'mime': 'text/xml'},
#             'opml': {'detail': 'OPML', 'ext': 'opml', 'mime': 'text/x-opml'},
#             'org': {'detail': 'Emacs Org mode',
#                     'ext': 'org',
#                     'mime': 'text/org'},
#             'pdf': {'detail': 'PDF', 'ext': 'pdf', 'mime': 'application/pdf'},
#             'plain': {'detail': 'plain text',
#                       'ext': 'txt',
#                       'mime': 'text/plain'},
#             'pptx': {'detail': 'PowerPoint slide show',
#                      'ext': 'pptx',
#                      'mime': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'},
#             'revealjs': {'detail': 'reveal.js HTML5 + JavaScript slide show',
#                          'ext': 'html',
#                          'mime': 'text/html'},
#             'rst': {'detail': 'reStructuredText',
#                     'ext': 'rst',
#                     'mime': 'text/x-rst'},
#             'rtf': {'detail': 'Rich Text Format',
#                     'ext': 'rtf',
#                     'mime': 'application/rtf'},
#             's5': {'detail': 'S5 HTML and JavaScript slide show',
#                    'ext': 'html',
#                    'mime': 'text/html'},
#             'slideous': {'detail': 'Slideous HTML and JavaScript slide show',
#                          'ext': 'html',
#                          'mime': 'text/html'},
#             'slidy': {'detail': 'Slidy HTML and JavaScript slide show',
#                       'ext': 'html',
#                       'mime': 'text/html'},
#             'texinfo': {'detail': 'GNU Texinfo',
#                         'ext': 'texi',
#                         'mime': 'application/x-texinfo'},
#             'textile': {'detail': 'Textile',
#                         'ext': 'textile',
#                         'mime': 'text/x-textile'},
#             'xwiki': {'detail': 'XWiki markup',
#                       'ext': 'txt',
#                       'mime': 'text/plain'},
#             'zimwiki': {'detail': 'ZimWiki markup',
#                         'ext': 'txt',
#                         'mime': 'text/plain'}}}

# %% [markdown]
# Wow, that's a lot of formats!
#
# Let's try converting the README from markdown into a pdf. We'll use the `/from/<in_fmt>/to/<out_fmt>` endpoint to accomplish that; in this case, it'll be `/from/markdown/to/pdf`.

# %%
outfile_path = 'README.pdf'

with open('README.md', 'rb') as infile:
    target_url = os.path.join(REFORMED_BASE_URL, "from", "markdown", "to", "pdf")
    print(f"Accessing {target_url} (this will likely take up to 30 seconds)...")

    response = requests.post(target_url, files={'document': infile})

    with open(outfile_path, mode='wb') as outfile:
        outfile.write(response.content)
        
    print(f"...response saved as {outfile_path}")
# Out:
# Accessing http://localhost:8005/api/v1/from/markdown/to/pdf (this will likely take up to 30 seconds)...
# ...Response saved as README.pdf

# %%
# we'll need to declare a PDF viewer to view the PDF inline in this notebook
# (borrowed from https://stackoverflow.com/a/19470377/346905)
class PDF(object):
  def __init__(self, pdf, size=(200,200)):
    self.pdf = pdf
    self.size = size

  def _repr_html_(self):
    return '<iframe src={0} width={1[0]} height={1[1]}></iframe>'.format(self.pdf, self.size)

  def _repr_latex_(self):
    return r'\includegraphics[width=1.0\textwidth]{{{0}}}'.format(self.pdf)

# let's vew the PDF, too
PDF("README.pdf", size=(1200, 500))
# Out:
# \includegraphics[width=1.0\textwidth]{README.pdf}
